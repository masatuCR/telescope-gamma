# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
cols=["fLength","fWidth","fSize","fConc","fConc1","fAsym","fM3Long","fM3Trans","fAlpha","fDist","class"]
df=pd.read_csv("magic04.data",names=cols)
df
# Out:
#         fLength    fWidth   fSize   fConc  fConc1     fAsym   fM3Long  \
# 0       28.7967   16.0021  2.6449  0.3918  0.1982   27.7004   22.0110
# 1       31.6036   11.7235  2.5185  0.5303  0.3773   26.2722   23.8238
# 2      162.0520  136.0310  4.0612  0.0374  0.0187  116.7410  -64.8580
# 3       23.8172    9.5728  2.3385  0.6147  0.3922   27.2107   -6.4633
# 4       75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277   28.5525
# ...         ...       ...     ...     ...     ...       ...       ...
# 19015   21.3846   10.9170  2.6161  0.5857  0.3934   15.2618   11.5245
# 19016   28.9452    6.7020  2.2672  0.5351  0.2784   37.0816   13.1853
# 19017   75.4455   47.5305  3.4483  0.1417  0.0549   -9.3561   41.0562
# 19018  120.5135   76.9018  3.9939  0.0944  0.0683    5.8043  -93.5224
# 19019  187.1814   53.0014  3.2093  0.2876  0.1539 -167.3125 -168.4558
#
#        fM3Trans   fAlpha     fDist class
# 0       -8.2027  40.0920   81.8828     g
# 1       -9.9574   6.3609  205.2610     g
# 2      -45.2160  76.9600  256.7880     g
# 3       -7.1513  10.4490  116.7370     g
# 4       21.8393   4.6480  356.4620     g
# ...         ...      ...       ...   ...
# 19015    2.8766   2.4229  106.8258     h
# 19016   -2.9632  86.7975  247.4560     h
# 19017   -9.4662  30.2987  256.5166     h
# 19018  -63.8389  84.6874  408.3166     h
# 19019   31.4755  52.7310  272.3174     h
#
# [19020 rows x 11 columns]

# %%
df["class"]=(df["class"]=="g").astype(int)

# %%
df.head(20)
# Out:
#      fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 0    28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1    31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2   162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3    23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4    75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
# 5    51.6240   21.1502  2.9085  0.2420  0.1340   50.8761  43.1887    9.8145
# 6    48.2468   17.3565  3.0332  0.2529  0.1515    8.5730  38.0957   10.5868
# 7    26.7897   13.7595  2.5521  0.4236  0.2174   29.6339  20.4560   -2.9292
# 8    96.2327   46.5165  4.1540  0.0779  0.0390  110.3550  85.0486   43.1844
# 9    46.7619   15.1993  2.5786  0.3377  0.1913   24.7548  43.8771   -6.6812
# 10   62.7766   29.9104  3.3331  0.2475  0.1261  -33.9065  57.5848   23.7710
# 11   18.8562   16.4600  2.4385  0.5282  0.2933   25.1269  -6.5401  -16.9327
# 12   45.6321   22.7100  3.0441  0.2213  0.1215  -18.3986 -20.6427  -14.3164
# 13   33.1818   12.4655  2.4955  0.4696  0.2412  -17.0341 -22.0762   -8.1803
# 14   60.4580   33.1061  3.1944  0.4679  0.2464   14.3000 -33.8765   28.8315
# 15   29.4741   22.4581  2.6258  0.3077  0.1740   18.1242  22.7035   13.1673
# 16   36.1741   17.6865  2.9460  0.2865  0.1591   -4.7746 -18.9697   11.3256
# 17   46.2915   16.0328  2.7756  0.3403  0.1920   49.9706  33.3653  -12.7979
# 18   46.0588   18.7870  3.2217  0.2431  0.1504   49.2704  34.1066   10.7955
# 19   44.7394   15.6364  2.6380  0.3107  0.1715   14.0430  37.2246   12.4183
#
#      fAlpha     fDist  class
# 0   40.0920   81.8828      1
# 1    6.3609  205.2610      1
# 2   76.9600  256.7880      1
# 3   10.4490  116.7370      1
# 4    4.6480  356.4620      1
# 5    3.6130  238.0980      1
# 6    4.7920  219.0870      1
# 7    0.8120  237.1340      1
# 8    4.8540  248.2260      1
# 9    7.8750  102.2510      1
# 10   9.9144  323.0940      1
# 11  11.4610  162.8480      1
# 12   0.3822  178.2550      1
# 13  41.9290   41.3816      1
# 14   8.2920  372.5680      1
# 15  48.0364  214.1260      1
# 16   0.2540  191.4550      1
# 17  38.7070   75.5234      1
# 18   8.6860  180.7830      1
# 19   3.2510  221.8060      1

# %%
for label in cols:
    plt.hist(df[df['class']==1][label].head(20), color='blue', label='gamma', alpha=0.7 ,density=True)
    plt.hist(df[df['class']==0][label].head(20), color='red', label='hadron', alpha=0.7 ,density=True)
    plt.title(label)
    plt.xlabel(label)
    plt.ylabel('Probability')
    plt.legend()
    plt.show()

# %%
df['class'].value_counts()
int(0.6*len(df))
# Out:
# 11412

# %%
#splitting dataset into training, validation and test sets
train,validation,test=np.split(df.sample(frac=1),[int(0.6*len(df)),int(0.8*len(df))])
# Out:
# C:\Users\simeo\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
print('train data:',len(train) ,' ', 'validation set:',' ',len(validation),'test set:',' ',len(test))
# Out:
# train data: 11412   validation set:   3804 test set:   3804

# %%
#check correlation in number of counts in the training set
print("gamma particles:",len(train[train['class']==1]))
print("gamma particles:",len(train[train['class']==0]))
# Out:
# gamma particles: 7357
# gamma particles: 4055

# %%
def scale_dataset(dataframe,oversample=False):
    X=dataframe[dataframe.columns[:-1]].values
    y=dataframe[dataframe.columns[-1]].values

    scaler=StandardScaler()
    X=scaler.fit_transform(X) #scale input features

    if oversample:
        ros=RandomOverSampler()
        X,y=ros.fit_resample(X,y) # perform oversampling

    data=np.hstack((X,(np.reshape(y,(-1,1))))) #combine columns of array X and that of vector y to create a new array 'data'

    return data,X,y

# %%
train,X_train,y_train=scale_dataset(train,oversample=True) #perform oversampling in training set only
validation,X_validation,y_validation=scale_dataset(validation,oversample=False)
test,X_test,y_test=scale_dataset(test,oversample=False)

# %%
knn_model=KNeighborsClassifier(n_neighbors=5)
knn_model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
knn_predictions=knn_model.predict(X_test)
knn_predictions
# Out:
# array([1, 0, 0, ..., 1, 1, 1])

# %%
y_test
# Out:
# array([1, 1, 1, ..., 1, 0, 1])

# %%
print(classification_report(y_test,knn_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.73      0.72      1284
#            1       0.86      0.85      0.86      2520
#
#     accuracy                           0.81      3804
#    macro avg       0.79      0.79      0.79      3804
# weighted avg       0.81      0.81      0.81      3804
